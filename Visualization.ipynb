# %%
# import basic libraries
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
# seaborn has a inbuilt dataset
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# load iris data
data=sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Relational Plots
#
# Relational plots are used to understand relationship between two variables.
#
# * Line plot
# * Scatter plot
# * Replot

# %%
# line plot
sns.lineplot(data=data,x="sepal_length",y="sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
# line plot
sns.lineplot(data=data,x="sepal_length",y="sepal_width",color="green")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data=data,x='sepal_length',y='sepal_width',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data=data,x='sepal_length',y='sepal_width',hue='species',ci=None)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Scatter

# %%
sns.scatterplot(data=data,x='petal_width',y='petal_length')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=data,x='petal_width',y='petal_length',hue='species')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=data,x='petal_width',y='petal_length',hue='species',palette='rainbow')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Rel Plot
#
# relplot by default it is scatter plot
#
# relplot can be converted into line plot by giving kind=line

# %%
sns.relplot(data=data,x='petal_length',y='sepal_width')

# %%
sns.relplot(data=data,x='petal_length',y='sepal_width',kind='line')

# %%
sns.relplot(data=data,x='petal_length',y='sepal_width',kind='line',ci=None)

# %% [markdown]
# # Categorical plots
#
# It is used to analyse one numerical and one categorical column.
#
# * Count plot
# * Box plot
# * Bar plot
# * Violin Plot
# * Strip plot
# * Swarm plot
# * Cat plot

# %%
# Count plot
# It just gives count of categories
sns.countplot(data=data,x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# bar plot
sns.barplot(data=data,x='species',y='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(data=data,x='species',y='sepal_width')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
# box plot

# it is used to identify outliers

sns.boxplot(data=data,x='species',y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=data,x='species',y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.boxplot(data=data,x='petal_length')
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.boxplot(data=data,x='petal_width')
# Out:
# <Axes: xlabel='petal_width'>

# %%
# Violin plot
sns.violinplot(data=data,x='petal_length')
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.violinplot(data=data,x='petal_width')
# Out:
# <Axes: xlabel='petal_width'>

# %%
sns.violinplot(data=data,x='species',y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.violinplot(data=data,x='species',)
# Out:
# <Axes: xlabel='species'>

# %%
# strip plot
sns.stripplot(data=data,x='species')
# Out:
# <Axes: xlabel='species'>

# %%
sns.stripplot(data=data,x='species',y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.stripplot(data=data,x='species',y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
# swarm plot
sns.swarmplot(data=data,x='species')
# Out:
# <Axes: xlabel='species'>

# %%
sns.swarmplot(data=data,x='species', y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.swarmplot(data=data,x='species', y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
# catplot
sns.catplot(data=data,x='species')

# %%
sns.catplot(data=data,x='species',y='petal_length')

# %%
sns.catplot(data=data,x='species',y='petal_width')

# %% [markdown]
# # Distribution Plot

# %%
# Histogram plot
# Dist plot
# These two graphs are used to check distribution of data

# %%
sns.histplot(data=data,x='petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=data,x='petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=data,x='species',y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.histplot(data=data,x='species',y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.histplot(data=data,x='species',y='petal_length',kde=True,hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.histplot(data=data,x='petal_width',kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
# dist plot
sns.distplot(x=data['sepal_length'])
# Out:
# <Axes: ylabel='Density'>

# %%
# pair plot
sns.pairplot(data=data,hue='species')
